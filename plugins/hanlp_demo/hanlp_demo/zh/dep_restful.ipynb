# %% [markdown]
# <a href="https://colab.research.google.com/github/Suzy126/HanLP/blob/doc-zh/plugins/hanlp_demo/hanlp_demo/zh/dep_restful.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align="center">点击下列图标在线运行HanLP</h2>
# <div align="center">
# 	<a href="https://colab.research.google.com/github/hankcs/HanLP/blob/doc-zh/plugins/hanlp_demo/hanlp_demo/zh/dep_restful.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# 	<a href="https://mybinder.org/v2/gh/hankcs/HanLP/doc-zh?filepath=plugins%2Fhanlp_demo%2Fhanlp_demo%2Fzh%2Fdep_restful.ipynb" target="_blank"><img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/></a>
# </div>
#
# ## 安装

# %% [markdown]
# 无论是Windows、Linux还是macOS，HanLP的安装只需一句话搞定：

# %%
# !pip install hanlp_restful -U
# Out:
# Collecting hanlp_restful
#   Downloading hanlp_restful-0.0.24.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hanlp_common (from hanlp_restful)
#   Downloading hanlp_common-0.0.23.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phrasetree>=0.0.9 (from hanlp_common->hanlp_restful)
#   Downloading phrasetree-0.0.9.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: hanlp_restful, hanlp_common, phrasetree
#   Building wheel for hanlp_restful (setup.py) ... done
#   Created wheel for hanlp_restful: filename=hanlp_restful-0.0.24-py3-none-any.whl size=10695 sha256=f524af208011facc11a8e4a08689139b1f76e452808951555693a1aec65d4a88
#   Stored in directory: /root/.cache/pip/wheels/e9/07/32/dba830d4e574da952be5cfe1ddde228a36bce718d505b87342
#   Building wheel for hanlp_common (setup.py) ... done
#   Created wheel for hanlp_common: filename=hanlp_common-0.0.23-py3-none-any.whl size=30821 sha256=2bf7049dfaa36b6c255d795fa4cbbb63c19a4d4ef81c47e1ad081563e766be64
#   Stored in directory: /root/.cache/pip/wheels/ef/47/32/3d848e78d5915f1b285bbb6926205ce96d188f2c262c75da70
#   Building wheel for phrasetree (setup.py) ... done
#   Created wheel for phrasetree: filename=phrasetree-0.0.9-py3-none-any.whl size=44218 sha256=1394913f512336620bbc3aa4361ab70e95cf0fba649ecd9592ba4a8216e026fc
#   Stored in directory: /root/.cache/pip/wheels/b4/20/a9/c514d2f4680dfb82e858581c0a4348f8703565012b777863de
# Successfully built hanlp_restful hanlp_common phrasetree
# Installing collected packages: phrasetree, hanlp_common, hanlp_restful
# Successfully installed hanlp_common-0.0.23 hanlp_restful-0.0.24 phrasetree-0.0.9

# %% [markdown]
# ## 创建客户端

# %%
from hanlp_restful import HanLPClient
HanLP = HanLPClient('https://www.hanlp.com/api', auth="NzkxM0BiYnMuaGFubHAuY29tOmVDZWV1WXRRNFpJZ0xUQ3o=", language='zh') # auth不填则匿名，zh中文，mul多语种

# %% [markdown]
# #### 申请秘钥
# 由于服务器算力有限，匿名用户每分钟限2次调用。如果你需要更多调用次数，[建议申请免费公益API秘钥auth](https://bbs.hanlp.com/t/hanlp2-1-restful-api/53)。

# %%
with open('test.txt', 'r') as f:
    sentences = [line.strip() for line in f if line.strip()]

results = HanLP(sentences, tasks=['dep'])
for idx, dep in enumerate(results['dep']):
    print(results)
# Out:
# {
#   "tok/fine": [
#     ["不行", "了", "，", "我", "得", "赶紧", "回去", "，", "管", "着", "那", "帮", "坏人", "请罪", "，", "让", "他们", "老老实实"],
#     ["他", "并没有", "去", "搭救", "她", "，", "现有", "，", "他", "已经", "老老实实", "，", "实话实说", "了"]
#   ],
#   "dep": [
#     [[0, "root"], [1, "dep"], [1, "punct"], [7, "nsubj"], [7, "xcomp"], [7, "advmod"], [1, "dep"], [7, "punct"], [7, "conj"], [9, "aux:asp"], [13, "det"], [11, "mark:clf"], [9, "dobj"], [9, "conj"], [7, "punct"], [7, "conj"], [16, "dobj"], [16, "ccomp"]],
#     [[4, "nsubj"], [4, "advmod"], [4, "xcomp"], [0, "root"], [4, "dobj"], [4, "punct"], [4, "dep"], [11, "punct"], [13, "nsubj"], [13, "advmod"], [4, "advmod"], [13, "punct"], [4, "conj"], [13, "dep"]]
#   ]
# }
# {
#   "tok/fine": [
#     ["不行", "了", "，", "我", "得", "赶紧", "回去", "，", "管", "着", "那", "帮", "坏人", "请罪", "，", "让", "他们", "老老实实"],
#     ["他", "并没有", "去", "搭救", "她", "，", "现有", "，", "他", "已经", "老老实实", "，", "实话实说", "了"]
#   ],
#   "dep": [
#     [[0, "root"], [1, "dep"], [1, "punct"], [7, "nsubj"], [7, "xcomp"], [7, "advmod"], [1, "dep"], [7, "punct"], [7, "conj"], [9, "aux:asp"], [13, "det"], [11, "mark:clf"], [9, "dobj"], [9, "conj"], [7, "punct"], [7, "conj"], [16, "dobj"], [16, "ccomp"]],
#     [[4, "nsubj"], [4, "advmod"], [4, "xcomp"], [0, "root"], [4, "dobj"], [4, "punct"], [4, "dep"], [11, "punct"], [13, "nsubj"], [13, "advmod"], [4, "advmod"], [13, "punct"], [4, "conj"], [13, "dep"]]
#   ]
# }

# %% [markdown]
# ## 依存句法分析
# 任务越少，速度越快。如指定仅执行依存句法分析：

# %%
doc = HanLP('2021年HanLPv2.1为生产环境带来次世代最先进的多语种NLP技术。', tasks='dep')

# %% [markdown]
# 返回值为一个[Document](https://hanlp.hankcs.com/docs/api/common/document.html):

# %%
print(doc)
# Out:
# {
#   "tok/fine": [
#     ["2021年", "HanLPv2.1", "为", "生产", "环境", "带来", "次", "世代", "最", "先进", "的", "多", "语种", "NLP", "技术", "。"]
#   ],
#   "dep": [
#     [[6, "tmod"], [6, "nsubj"], [6, "prep"], [5, "nn"], [3, "pobj"], [0, "root"], [8, "clf"], [10, "dep"], [10, "advmod"], [15, "rcmod"], [10, "cpm"], [13, "nummod"], [15, "nn"], [15, "nn"], [6, "dobj"], [6, "punct"]]
#   ]
# }

# %% [markdown]
# `doc['dep']`为句子们的依存句法树列表，第`i`个二元组表示第`i`个单词的`[中心词的下标, 与中心词的依存关系]`。

# %% [markdown]
# 可视化依存句法树：

# %%
doc.pretty_print()
# Out:
# <div style="display: table; padding-bottom: 1rem;"><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap; line-height: 128%; padding: 0;">Dep&nbsp;Tree&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>────────────&nbsp;<br>&nbsp;&nbsp;&nbsp;┌───────►&nbsp;<br>&nbsp;&nbsp;&nbsp;│┌──────►&nbsp;<br>&nbsp;&nbsp;&nbsp;││&nbsp;&nbsp;&nbsp;┌──►&nbsp;<br>&nbsp;&nbsp;&nbsp;││&nbsp;&nbsp;&nbsp;│┌─►&nbsp;<br>&nbsp;&nbsp;&nbsp;││┌─►└┴──&nbsp;<br>┌┬─┴┴┴──────&nbsp;<br>││&nbsp;&nbsp;┌──────►&nbsp;<br>││&nbsp;&nbsp;│&nbsp;&nbsp;&nbsp;&nbsp;┌─►&nbsp;<br>││&nbsp;&nbsp;│┌──►├──&nbsp;<br>││&nbsp;&nbsp;││&nbsp;&nbsp;&nbsp;└─►&nbsp;<br>││&nbsp;&nbsp;││&nbsp;&nbsp;&nbsp;┌─►&nbsp;<br>││&nbsp;&nbsp;││┌─►└──&nbsp;<br>││&nbsp;&nbsp;│││&nbsp;&nbsp;┌─►&nbsp;<br>│└─►└┴┴──┴──&nbsp;<br>└──────────►&nbsp;</pre><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap; line-height: 128%; padding: 0;">Token&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>─────────&nbsp;<br>2021年&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>HanLPv2.1&nbsp;<br>为&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>生产&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>环境&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>带来&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>次世代&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>最&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>先进&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>的&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>多&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>语种&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>NLP&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>技术&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>。&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</pre><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap; line-height: 128%; padding: 0;">Relation&nbsp;&nbsp;&nbsp;<br>───────────<br>nmod:tmod&nbsp;&nbsp;<br>nsubj&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>case&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>compound:nn<br>nmod:prep&nbsp;&nbsp;<br>root&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>dep&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>advmod&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>amod&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>mark&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>dep&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>compound:nn<br>compound:nn<br>dobj&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>punct&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</pre></div>

# %% [markdown]
# 转换为CoNLL格式：

# %%
print(doc.to_conll())
# Out:
# 1	2021年	_	_	_	_	6	tmod	_	_
# 2	HanLPv2.1	_	_	_	_	6	nsubj	_	_
# 3	为	_	_	_	_	6	prep	_	_
# 4	生产	_	_	_	_	5	nn	_	_
# 5	环境	_	_	_	_	3	pobj	_	_
# 6	带来	_	_	_	_	0	root	_	_
# 7	次	_	_	_	_	8	clf	_	_
# 8	世代	_	_	_	_	10	dep	_	_
# 9	最	_	_	_	_	10	advmod	_	_
# 10	先进	_	_	_	_	15	rcmod	_	_
# 11	的	_	_	_	_	10	cpm	_	_
# 12	多	_	_	_	_	13	nummod	_	_
# 13	语种	_	_	_	_	15	nn	_	_
# 14	NLP	_	_	_	_	15	nn	_	_
# 15	技术	_	_	_	_	6	dobj	_	_
# 16	。	_	_	_	_	6	punct	_	_

# %% [markdown]
# 为已分词的句子执行依存句法分析：

# %%
HanLP(tokens=[
    ["HanLP", "为", "生产", "环境", "带来", "次世代", "最", "先进", "的", "多语种", "NLP", "技术", "。"],
    ["我", "的", "希望", "是", "希望", "张晚霞", "的", "背影", "被", "晚霞", "映红", "。"]
  ], tasks='dep').pretty_print()
# Out:
# Dep Tree   	Token	Relati
# ───────────	─────	──────
#  ┌────────►	HanLP	nsubj
#  │┌─►┌─────	为    	prep
#  ││  │  ┌─►	生产   	nn
#  ││  └─►└──	环境   	pobj
# ┌┼┴────────	带来   	root
# ││     ┌──►	次世代  	dep
# ││     │┌─►	最    	advmod
# ││  ┌─►└┼──	先进   	rcmod
# ││  │   └─►	的    	cpm
# ││  │  ┌──►	多语种  	nn
# ││  │  │┌─►	NLP  	nn
# │└─►└──┴┴──	技术   	dobj
# └─────────►	。    	punct
#
# Dep Tree        	Tok	Relation
# ────────────────	───	─────────
#           ┌─►┌──	我  	assmod
#           │  └─►	的  	assm
#        ┌─►└─────	希望 	top
# ┌┬─────┴────────	是  	root
# │└─►┌───────────	希望 	ccomp
# │   │     ┌─►┌──	张晚霞	assmod
# │   │     │  └─►	的  	assm
# │   │  ┌─►└─────	背影 	nsubjpass
# │   └─►└──┬─────	被  	ccomp
# │         │  ┌─►	晚霞 	nsubj
# │         └─►└──	映红 	dep
# └──────────────►	。  	punct
